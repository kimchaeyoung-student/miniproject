# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import folium
import urllib

# %%
df2019 = pd.read_csv('5조/2019.csv',encoding='cp949')

# %%
df2020 = pd.read_csv('5조/2020.csv',encoding='cp949')

# %%
df2019.head(4)
# Out:
#                  id  Unnamed: 1 fclt_name ctprvn_nm sgnr_nm  legaldong_cd  \
# 0  KC488PO20N000001         NaN  블루거제페스티벌      경상남도     거제시    4831010200
# 1  KC488PO20N000002         NaN   바다로 세계로      경상남도     거제시    4831010900
# 2  KC488PO20N000015         NaN    송년불꽃축제      경상남도     거제시    4831010200
# 3  KC488PO20N000016         NaN    춘천마임축제       강원도     춘천시    4211011200
#
#    legaldong_cd_si  legaldong_cd_gu legalemd_nm     adstrd_cd  ...  \
# 0               48            48310        장승포동  4.831051e+09  ...
# 1               48            48310         고현동  4.831058e+09  ...
# 2               48            48310        장승포동  4.831051e+09  ...
# 3               42            42110         효자동  4.211062e+09  ...
#
#           telno                         hmpg rlt_inf  data_stdde prvd_agnc_cd  \
# 0  055-680-1000                          NaN     NaN    20200213      5370000
# 1  055-639-4173                          NaN     NaN    20200213      5370000
# ...

# %%
type(df2019['legaldong_cd'][0])
# Out:
# numpy.int64

# %% [markdown]
# zip코드

# %% [markdown]
# 2019/2020년 축제

# %%
m = folium.Map(location=[129.039878,35.1508797],zoom_start=10)
long = df2019['x_cd'].mean()
lat = df2019['y_cd'].mean()
m = folium.Map(location=[lat,long],zoom_start=10)
for i in df2019.index:
#     tooltip = busan.loc[i,'상호명']+'-'+ busan.loc[i,'도로명주소']
    lat = df2019.loc[i,'x_cd']
    long = df2019.loc[i,'y_cd']
    folium.CircleMarker(
        location=[lat,long],
        radius=1,
#         popup="Laurelhurst Park",
        color="red",
        fill=True,
        fill_color="#9999",
    ).add_to(m)
for i in df2020.index:
#     tooltip = df2020.loc[i,'상호명']+'-'+ df2020.loc[i,'도로명주소']
    lat = df2020.loc[i,'x_cd']
    long = df2020.loc[i,'y_cd']
    folium.CircleMarker(
        location=[lat,long],
        radius=1,
#         popup="Laurelhurst Park",
        color="#0000cc",
        fill=True,
        fill_color="#0000",
    ).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
m = folium.Map(location=[129.039878,35.1508797],zoom_start=10)
long = df2019['x_cd'].mean()
lat = df2019['y_cd'].mean()
m = folium.Map(location=[lat,long],zoom_start=10)
for i in df2019.index:
#     tooltip = busan.loc[i,'상호명']+'-'+ busan.loc[i,'도로명주소']
    lat = df2019.loc[i,'x_cd']
    long = df2019.loc[i,'y_cd']
    folium.CircleMarker(
        location=[lat,long],
        radius=1,
#         popup="Laurelhurst Park",
        color="red",
        fill=True,
        fill_color="#9999",
        
        
for i in range (0,len(df2019)) : 
    if int(df2019['legaldong_cd_si'][i])==48 :
        print(df2019['x_cd'][i],df2019['y_cd'][i])
# Out:
# 34.86717826 128.7233592
# 34.88052883 128.6208143
# 34.8663093 128.7246401
# 34.77438469 128.6408652
# 35.389081 128.477232
# 34.85656738 128.579596
# 35.25542023 128.4227474
# 35.30883803 128.5185567
# 35.28326216 128.4001528
# 34.90219568 128.7140612
# 35.43772692 128.5886091
# 35.05322615 128.3920276
# 35.23606039 128.8730826
# 35.25149561 128.745857
# 35.00361954 128.0642075
# 35.52424257 127.7206714
# 35.48686206 128.9860377
# 35.38015379 128.9211173
# 35.42085217 128.9410364
# 35.37762785 129.1434288

# %% [markdown]
# 2019년 경상남도 축제 표시

# %%
m = folium.Map(location=[129.039878,35.1508797],zoom_start=10)
long = df2019['x_cd'].mean()
lat = df2019['y_cd'].mean()
m = folium.Map(location=[lat,long],zoom_start=10)
for i in range (0,len(df2019)) : 
    if int(df2019['legaldong_cd_si'][i])==48 :
        lat = df2019['x_cd'][i]
        long = df2019['y_cd'][i]
        folium.CircleMarker(
            location=[lat,long],
            radius=1,
            color="red",
            fill=True,
            fill_color="#9999",
        ).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %% [markdown]
# 워드클라우드

# %%
pip install BeautifulSoup
# Out:
# Note: you may need to restart the kernel to use updated packages.Collecting BeautifulSoup
#
#   Using cached BeautifulSoup-3.2.2.tar.gz (32 kB)
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\ad\miniconda3\python.exe' -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\ad\\AppData\\Local\\Temp\\pip-install-gijho4no\\beautifulsoup_75b2761e196e425e95a00544e58369c3\\setup.py'"'"'; __file__='"'"'C:\\Users\\ad\\AppData\\Local\\Temp\\pip-install-gijho4no\\beautifulsoup_75b2761e196e425e95a00544e58369c3\\setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\ad\AppData\Local\Temp\pip-pip-egg-info-g_rnw8bw'
#          cwd: C:\Users\ad\AppData\Local\Temp\pip-install-gijho4no\beautifulsoup_75b2761e196e425e95a00544e58369c3\
#     Complete output (6 lines):
#     Traceback (most recent call last):
# ...

# %%
from bs4 import BeautifulSoup
import urllib.request
from urllib.parse import quote
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-246-6f9cdfb33012> in <module>
# ----> 1 from bs4 import BeautifulSoup
#       2 import urllib.request
#       3 from urllib.parse import quote
#       4 import pandas as pd
#
# ModuleNotFoundError: No module named 'bs4'

# %%
df2019.columns
# Out:
# Index(['id', 'Unnamed: 1', 'fclt_name', 'ctprvn_nm', 'sgnr_nm', 'legaldong_cd',
#        'legaldong_cd_si', 'legaldong_cd_gu', 'legalemd_nm', 'adstrd_cd',
#        'adstrd_nm', 'rdnmaddr_cd', 'rdnm_addr', 'zip_cd', 'grid_cd', 'x_cd',
#        'y_cd', 'opmt_plce', 'fstvl_bgn_dt', 'fstvl_bgn_dt_year',
#        'fstvl_bgn_dt_month', 'fstvl_bgn_dt_day', 'fstvl_end_dt',
#        'fstvl_end_dt_year', 'fstvl_end_dt_month', 'fstvl_end_dt_day',
#        'fstvl_cn', 'mnnst', 'auspc_instt', 'supt_instt', 'telno', 'hmpg',
#        'rlt_inf', 'data_stdde', 'prvd_agnc_cd', 'prvd_agnc_nm', 'lst_updt_dt',
#        'data_orgn', 'FILE_NAME', 'base_ymd'],
#       dtype='object')

# %%
df2019['fclt_name'][0]
# Out:
# '블루거제페스티벌'

# %%
query = urllib.parse.quote(df2019['fclt_name'][0])
s_year = df2019['fstvl_bgn_dt_year'][0]
s_month = format(df2019['fstvl_bgn_dt_month'][0],'02')
# s_day = format(df2019['fstvl_bgn_dt_day'][0],'02')

d_year = df2019['fstvl_end_dt_year'][0]
d_month = format(df2019['fstvl_end_dt_month'][0],'02')
# d_day = format(df2019['fstvl_end_dt_day'][0],'02')


url = 'https://search.naver.com/search.naver?where=news&query={}&sm=tab_opt&sort=0&photo=0&field=0&pd=3&ds={}.{}.00&de={}.{}.32'.format(query,s_year,s_month,d_year,d_month)
# Out:
# https://search.naver.com/search.naver?where=news&query=%EB%B8%94%EB%A3%A8%EA%B1%B0%EC%A0%9C%ED%8E%98%EC%8A%A4%ED%8B%B0%EB%B2%8C&sm=tab_opt&sort=0&photo=0&field=0&pd=3&ds=2019.07.00&de=2019.08.32

# %%
query = df2019['fclt_name'][0]
s_year = df2019['fstvl_bgn_dt_year'][0]
s_month = df2019['fstvl_bgn_dt_month'][0]
s_day = df2019['fstvl_bgn_dt_day'][0]
d_year = df2019['fstvl_end_dt_year'][0]
d_month = format(df2019['fstvl_end_dt_month'][0],'02')

d_day = df2019['fstvl_end_dt_day'][0]

# %%
search_url = urllib.request.urlopen(url).read()
soup = BeautifulSoup(search_url,'html.parser')
soup
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-247-c58da59d3a15> in <module>
#       1 search_url = urllib.request.urlopen(url).read()
# ----> 2 soup = BeautifulSoup(search_url,'html.parser')
#       3 soup
#
# NameError: name 'BeautifulSoup' is not defined
